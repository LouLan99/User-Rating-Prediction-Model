# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm

# %%
df = pd.read_csv(filepath_or_buffer= "../data/Extract_Dataset.csv") 
df
# Out:
#       Unnamed: 0                     App Name  \
# 0              0                        Untap
# 1              1                Green Meadows
# 2              2                    YG SELECT
# 3              3                 Vinca Wealth
# 4              4                Drink recipes
# ...          ...                          ...
# 9995        9995  Deep Memorial Public School
# 9996        9996                Anchored Sins
# 9997        9997                 설운도 트로트 노래모음
# 9998        9998                          Coq
# 9999        9999                  Color Kraft
#
#                                     App Id       Category  Rating  \
# 0                                 in.untap  Entertainment     3.9
# 1     com.ooweboowebengineers.greenmeadows      Lifestyle     0.0
# 2             com.makeshop.powerapp.ygnext       Shopping     4.3
# 3                           com.bag4wealth        Finance     5.0
# 4                       com.drinks.recipes   Food & Drink     4.3
# ...                                    ...            ...     ...
# 9995                      com.edunext.dmps      Education     4.3
# 9996                com.goc.anchoredsins3D   Role Playing     NaN
# 9997                  korea.singer.sulundo  Music & Audio     5.0
# 9998                   fr.enfantdoudou.coq  Entertainment     0.0
# 9999                 com.ekraft.colorkraft         Casual     4.9
#
#       Rating Count  Installs  Minimum Installs  Maximum Installs  Free  ...  \
# 0             68.0   10,000+           10000.0             10291  True  ...
# 1              0.0       50+              50.0                90  True  ...
# 2            918.0  100,000+          100000.0            135038  True  ...
# 3              6.0       50+              50.0                53  True  ...
# 4            830.0  100,000+          100000.0            142498  True  ...
# ...            ...       ...               ...               ...   ...  ...
# 9995         142.0    1,000+            1000.0              2490  True  ...
# 9996           NaN        5+               5.0                 8  True  ...
# 9997           9.0    1,000+            1000.0              1035  True  ...
# 9998           0.0      500+             500.0               522  True  ...
# 9999          19.0      500+             500.0               656  True  ...
#
#                              Developer Website            Developer Email  \
# 0                             https://untap.in             hello@untap.in
# 1                         http://ooweboo.co.za          ray@ooweboo.co.za
# 2                       http://www.ygeshop.com     app.ygselect@gmail.com
# 3                       https://bag4wealth.com     acmatics.app@gmail.com
# 4                     http://cookwithlove.biz/   andrei.nazarco@gmail.com
# ...                                        ...                        ...
# 9995        http://www.edunexttechnologies.com      edunexttech@gmail.com
# 9996  https://www.gearoverclocked.com/projects  gearoverclocked@gmail.com
# 9997                       http://israng.co.kr      parkhanye28@gmail.com
# 9998                                       NaN          pridgua@gmail.com
# 9999                       http://ekraft.co.in   dakshpandyaweb@gmail.com
#
#           Released  Last Updated Content Rating  \
# 0      Nov 2, 2020  Nov 02, 2020       Everyone
# 1     May 29, 2017  May 29, 2017       Everyone
# 2     Jan 20, 2016  May 12, 2021       Everyone
# 3     Jun 30, 2020  May 11, 2021       Everyone
# 4     May 20, 2014  Jul 13, 2020       Everyone
# ...            ...           ...            ...
# 9995   Mar 4, 2016  Aug 26, 2020       Everyone
# 9996           NaN  Jan 03, 2020           Teen
# 9997  Apr 23, 2020  Feb 03, 2021           Teen
# 9998  Apr 16, 2020  Apr 16, 2020       Everyone
# 9999  Apr 24, 2015  Dec 23, 2015       Everyone
#
#                                          Privacy Policy Ad Supported  \
# 0                                                   NaN        False
# 1     http://appmc2.net/privacy?company=OOWEBOO%20We...        False
# 2                 http://www.ygeshop.com/m/privacy.html         True
# 3        https://bag4wealth.com/finnsys/app/privacy.php        False
# 4     http://cookwithlove.biz/privacy_policy/drink_r...         True
# ...                                                 ...          ...
# 9995  http://www.edunexttechnologies.com/terms-and-c...        False
# 9996                                                NaN        False
# 9997  https://docs.google.com/document/d/1C6-LdIQzH7...         True
# 9998  https://www.ftc.gov/tips-advice/business-cente...         True
# 9999                   http://ekraft.co.in/privacy.html         True
#
#      In App Purchases Editors Choice         Scraped Time
# 0               False          False  2021-06-16 11:24:00
# 1               False          False  2021-06-16 10:54:34
# 2               False          False  2021-06-16 02:21:54
# 3               False          False  2021-06-16 01:29:59
# 4               False          False  2021-06-16 08:43:51
# ...               ...            ...                  ...
# 9995            False          False  2021-06-16 00:56:34
# 9996            False          False  2021-06-16 02:44:16
# 9997            False          False  2021-06-16 12:40:44
# 9998            False          False  2021-06-16 12:06:11
# 9999            False          False  2021-06-15 22:07:22
#
# [10000 rows x 25 columns]

# %% [markdown]
# We can see that there is an index column called Unnamed, we need to make the first column index the primary index

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df
# Out:
#                          App Name                                App Id  \
# 0                           Untap                              in.untap
# 1                   Green Meadows  com.ooweboowebengineers.greenmeadows
# 2                       YG SELECT          com.makeshop.powerapp.ygnext
# 3                    Vinca Wealth                        com.bag4wealth
# 4                   Drink recipes                    com.drinks.recipes
# ...                           ...                                   ...
# 9995  Deep Memorial Public School                      com.edunext.dmps
# 9996                Anchored Sins                com.goc.anchoredsins3D
# 9997                 설운도 트로트 노래모음                  korea.singer.sulundo
# 9998                          Coq                   fr.enfantdoudou.coq
# 9999                  Color Kraft                 com.ekraft.colorkraft
#
#            Category  Rating  Rating Count  Installs  Minimum Installs  \
# 0     Entertainment     3.9          68.0   10,000+           10000.0
# 1         Lifestyle     0.0           0.0       50+              50.0
# 2          Shopping     4.3         918.0  100,000+          100000.0
# 3           Finance     5.0           6.0       50+              50.0
# 4      Food & Drink     4.3         830.0  100,000+          100000.0
# ...             ...     ...           ...       ...               ...
# 9995      Education     4.3         142.0    1,000+            1000.0
# 9996   Role Playing     NaN           NaN        5+               5.0
# 9997  Music & Audio     5.0           9.0    1,000+            1000.0
# 9998  Entertainment     0.0           0.0      500+             500.0
# 9999         Casual     4.9          19.0      500+             500.0
#
#       Maximum Installs  Free  Price  ...  \
# 0                10291  True    0.0  ...
# 1                   90  True    0.0  ...
# 2               135038  True    0.0  ...
# 3                   53  True    0.0  ...
# 4               142498  True    0.0  ...
# ...                ...   ...    ...  ...
# 9995              2490  True    0.0  ...
# 9996                 8  True    0.0  ...
# 9997              1035  True    0.0  ...
# 9998               522  True    0.0  ...
# 9999               656  True    0.0  ...
#
#                              Developer Website            Developer Email  \
# 0                             https://untap.in             hello@untap.in
# 1                         http://ooweboo.co.za          ray@ooweboo.co.za
# 2                       http://www.ygeshop.com     app.ygselect@gmail.com
# 3                       https://bag4wealth.com     acmatics.app@gmail.com
# 4                     http://cookwithlove.biz/   andrei.nazarco@gmail.com
# ...                                        ...                        ...
# 9995        http://www.edunexttechnologies.com      edunexttech@gmail.com
# 9996  https://www.gearoverclocked.com/projects  gearoverclocked@gmail.com
# 9997                       http://israng.co.kr      parkhanye28@gmail.com
# 9998                                       NaN          pridgua@gmail.com
# 9999                       http://ekraft.co.in   dakshpandyaweb@gmail.com
#
#           Released  Last Updated Content Rating  \
# 0      Nov 2, 2020  Nov 02, 2020       Everyone
# 1     May 29, 2017  May 29, 2017       Everyone
# 2     Jan 20, 2016  May 12, 2021       Everyone
# 3     Jun 30, 2020  May 11, 2021       Everyone
# 4     May 20, 2014  Jul 13, 2020       Everyone
# ...            ...           ...            ...
# 9995   Mar 4, 2016  Aug 26, 2020       Everyone
# 9996           NaN  Jan 03, 2020           Teen
# 9997  Apr 23, 2020  Feb 03, 2021           Teen
# 9998  Apr 16, 2020  Apr 16, 2020       Everyone
# 9999  Apr 24, 2015  Dec 23, 2015       Everyone
#
#                                          Privacy Policy Ad Supported  \
# 0                                                   NaN        False
# 1     http://appmc2.net/privacy?company=OOWEBOO%20We...        False
# 2                 http://www.ygeshop.com/m/privacy.html         True
# 3        https://bag4wealth.com/finnsys/app/privacy.php        False
# 4     http://cookwithlove.biz/privacy_policy/drink_r...         True
# ...                                                 ...          ...
# 9995  http://www.edunexttechnologies.com/terms-and-c...        False
# 9996                                                NaN        False
# 9997  https://docs.google.com/document/d/1C6-LdIQzH7...         True
# 9998  https://www.ftc.gov/tips-advice/business-cente...         True
# 9999                   http://ekraft.co.in/privacy.html         True
#
#      In App Purchases Editors Choice         Scraped Time
# 0               False          False  2021-06-16 11:24:00
# 1               False          False  2021-06-16 10:54:34
# 2               False          False  2021-06-16 02:21:54
# 3               False          False  2021-06-16 01:29:59
# 4               False          False  2021-06-16 08:43:51
# ...               ...            ...                  ...
# 9995            False          False  2021-06-16 00:56:34
# 9996            False          False  2021-06-16 02:44:16
# 9997            False          False  2021-06-16 12:40:44
# 9998            False          False  2021-06-16 12:06:11
# 9999            False          False  2021-06-15 22:07:22
#
# [10000 rows x 24 columns]

# %% [markdown]
# ### Data Dictionnary
# This is a data dictionnary for the project. It contains all the information about the dataset used to train and test the model.
#
# App Name:
#
#     - object
#     - The name of the application on the Google play store
#     -
# App Id:
#
#     - object
#     - The application have an unique identifiers
#     -
# Category:
#
#     - object
#     - The application belong to a specific category
#     -
# Rating:
#
#     - float64
#     -  This is the average rating for an application
#     -
# Rating Count:
#
#     - float64
#     - the number of person that rate the application
#     -
# Installs:
#
#     - object
#     -  the approximate number of install of the app
#     -
# Minimum Installs:
#
#     - float64
#     -
#     -
# Maximum Installs
#
#     - int64
#     -
#     -
# Free:
#
#     - bool
#     - The application doesnt cost
#     -
# Price:
#
#     - float64
#     -   The cost of the mobile application
#     -
# Currency:
#
#     - object
#     - The currency in which the price of the mobile application is listed
#     -
# Size:
#
#     - object
#     - The size of the mobile application in terms of storage space
#     -
# Minimum Android:
#
#     - object
#     -  The minimum version of the Android operating system required to run the mobile application.
#     -
# Developer Id:
#
#     - object
#     -  The developer has a unique identifier
#     -
# Developer Website:
#
#     - object
#     - The website associated with the developer or company behind the mobile application
#     -
# Developer Email:
#
#     - object
#     -  The email address of the developer or company responsible for the mobile application.
#     -
# Released:
#
#     - object
#     -   The date when the mobile application was initially released on the Google Play Store.
#     -
# Last Updated:
#
#     - object
#     -  The date when the mobile application was last updated
#     -
# Content Rating:
#
#     - object
#     - The content rating for which the mobile application is suitable
#     -
# Privacy Policy:
#
#     - object
#     -  A link to the privacy policy associated with the mobile application.
#     -
# Editors Choice:
#
#     - bool
#     -  the mobile application has been selected as an "Editor's Choice" on the Google Play Store.
#     -
# Scraped Time:
#
#     - object
#     -  The date where the data was collected in the google play store
#     -

# %% [markdown]
# ### Step 1: Check datatypes and format

# %%
df.shape
# Out:
# (10000, 24)

# %% [markdown]
# This DataFrame contains 10000 rows and 24 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   App Name           10000 non-null  object
#  1   App Id             10000 non-null  object
#  2   Category           10000 non-null  object
#  3   Rating             9906 non-null   float64
#  4   Rating Count       9906 non-null   float64
#  5   Installs           9999 non-null   object
#  6   Minimum Installs   9999 non-null   float64
#  7   Maximum Installs   10000 non-null  int64
#  8   Free               10000 non-null  bool
#  9   Price              10000 non-null  float64
#  10  Currency           9999 non-null   object
#  11  Size               9999 non-null   object
#  12  Minimum Android    9969 non-null   object
#  13  Developer Id       10000 non-null  object
#  14  Developer Website  6628 non-null   object
#  15  Developer Email    10000 non-null  object
#  16  Released           9694 non-null   object
#  17  Last Updated       10000 non-null  object
#  18  Content Rating     10000 non-null  object
#  19  Privacy Policy     8254 non-null   object
#  20  Ad Supported       10000 non-null  bool
#  21  In App Purchases   10000 non-null  bool
#  22  Editors Choice     10000 non-null  bool
#  23  Scraped Time       10000 non-null  object
# dtypes: bool(4), float64(4), int64(1), object(15)
# memory usage: 1.6+ MB

# %% [markdown]
# We can that see there are a mixture of numerical and categorical columns. There is lots of "object" type which corresponds to categorical data. We can also see that there is boolean data that might be some binary type columns which could be True/False or 0/1 which are captured as "yes"/"no". Finally, we see that there are some columns missing data in Rating, Rating Count ,Installs, Minimum Installs, Currency, Size, Minimum Android, Developer Website (this columns has the more null value compare to the other columns), Released and Privacy Policy.

# %% [markdown]
# ### Dropping Columns

# %%
df.drop(columns = ['Last Updated','App Name','Size','Minimum Android', 'App Id', 'Currency', 'Developer Website', 'Privacy Policy', 'Scraped Time', 'Developer Email', 'Developer Id', 'Installs', 'Released'], inplace= True)
# Out:
# C:\Users\lelon\AppData\Local\Temp\ipykernel_20648\1868572805.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns = ['Last Updated','App Name','Size','Minimum Android', 'App Id', 'Currency', 'Developer Website', 'Privacy Policy', 'Scraped Time', 'Developer Email', 'Developer Id', 'Installs', 'Released'], inplace= True)

# %% [markdown]
# We decided to drop those columns as they were not in use for our prediction analysis

# %% [markdown]
# ### Checking for duplicate data

# %%
df.duplicated().sum()
# Out:
# 742

# %% [markdown]
# There is some duplicated data, we will check with .value_counts which values is duplicated.

# %%
df.duplicated().value_counts()
# Out:
# False    9258
# True      742
# Name: count, dtype: int64

# %% [markdown]
# we can see that the duplicated value is related with the boolean values. Which is part of the data set and can be used to create dummies.

# %%
df.T.duplicated().sum()
# Out:
# 0

# %% [markdown]
# According to this command there is no ducplicate information

# %% [markdown]
# ### Dealing with missing data

# %%
df.isna().sum()
# Out:
# Category             0
# Rating              94
# Rating Count        94
# Minimum Installs     1
# Maximum Installs     0
# Free                 0
# Price                0
# Content Rating       0
# Ad Supported         0
# In App Purchases     0
# Editors Choice       0
# dtype: int64

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# Category            0.00
# Rating              0.94
# Rating Count        0.94
# Minimum Installs    0.01
# Maximum Installs    0.00
# Free                0.00
# Price               0.00
# Content Rating      0.00
# Ad Supported        0.00
# In App Purchases    0.00
# Editors Choice      0.00
# dtype: float64

# %% [markdown]
# We can see that there is few missing values.
# It is a small portion of the columns so we can drop the null values.

# %%
df.dropna(inplace = True)
# Out:
# C:\Users\lelon\AppData\Local\Temp\ipykernel_20648\1791587065.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9906 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Category          9906 non-null   object
#  1   Rating            9906 non-null   float64
#  2   Rating Count      9906 non-null   float64
#  3   Minimum Installs  9906 non-null   float64
#  4   Maximum Installs  9906 non-null   int64
#  5   Free              9906 non-null   bool
#  6   Price             9906 non-null   float64
#  7   Content Rating    9906 non-null   object
#  8   Ad Supported      9906 non-null   bool
#  9   In App Purchases  9906 non-null   bool
#  10  Editors Choice    9906 non-null   bool
# dtypes: bool(4), float64(4), int64(1), object(2)
# memory usage: 657.8+ KB

# %% [markdown]
# ### Changing some values into binary

# %%
df
# Out:
#            Category  Rating  Rating Count  Minimum Installs  Maximum Installs  \
# 0     Entertainment     3.9          68.0           10000.0             10291
# 1         Lifestyle     0.0           0.0              50.0                90
# 2          Shopping     4.3         918.0          100000.0            135038
# 3           Finance     5.0           6.0              50.0                53
# 4      Food & Drink     4.3         830.0          100000.0            142498
# ...             ...     ...           ...               ...               ...
# 9994          Music     0.0           0.0              10.0                14
# 9995      Education     4.3         142.0            1000.0              2490
# 9997  Music & Audio     5.0           9.0            1000.0              1035
# 9998  Entertainment     0.0           0.0             500.0               522
# 9999         Casual     4.9          19.0             500.0               656
#
#       Free  Price Content Rating  Ad Supported  In App Purchases  \
# 0     True    0.0       Everyone         False             False
# 1     True    0.0       Everyone         False             False
# 2     True    0.0       Everyone          True             False
# 3     True    0.0       Everyone         False             False
# 4     True    0.0       Everyone          True             False
# ...    ...    ...            ...           ...               ...
# 9994  True    0.0       Everyone         False             False
# 9995  True    0.0       Everyone         False             False
# 9997  True    0.0           Teen          True             False
# 9998  True    0.0       Everyone          True             False
# 9999  True    0.0       Everyone          True             False
#
#       Editors Choice
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ...              ...
# 9994           False
# 9995           False
# 9997           False
# 9998           False
# 9999           False
#
# [9906 rows x 11 columns]

# %% [markdown]
# To be able to change some of our values into binary we need to change the datatype in integer

# %%
df["Free"] = df["Free"].astype(int)
df["In App Purchases"] = df["In App Purchases"].astype(int)
df["Editors Choice"] = df["Editors Choice"].astype(int)
df["Ad Supported"] = df["Ad Supported"].astype(int)
# Out:
# C:\Users\lelon\AppData\Local\Temp\ipykernel_20648\860087706.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Free"] = df["Free"].astype(int)
# C:\Users\lelon\AppData\Local\Temp\ipykernel_20648\860087706.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["In App Purchases"] = df["In App Purchases"].astype(int)
# C:\Users\lelon\AppData\Local\Temp\ipykernel_20648\860087706.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Editors Choice"] = df["Editors Choice"].astype(int)
# C:\Users\lelon\AppData\Local\Temp\ipykernel_20648\860087706.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Ad Supported"] = df["Ad Supported"].astype(int)

# %% [markdown]
# we now can check if the datatype change was effective by using .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9906 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Category          9906 non-null   object
#  1   Rating            9906 non-null   float64
#  2   Rating Count      9906 non-null   float64
#  3   Minimum Installs  9906 non-null   float64
#  4   Maximum Installs  9906 non-null   int64
#  5   Free              9906 non-null   int32
#  6   Price             9906 non-null   float64
#  7   Content Rating    9906 non-null   object
#  8   Ad Supported      9906 non-null   int32
#  9   In App Purchases  9906 non-null   int32
#  10  Editors Choice    9906 non-null   int32
# dtypes: float64(4), int32(4), int64(1), object(2)
# memory usage: 773.9+ KB

# %%
df.head()
# Out:
#         Category  Rating  Rating Count  Minimum Installs  Maximum Installs  \
# 0  Entertainment     3.9          68.0           10000.0             10291
# 1      Lifestyle     0.0           0.0              50.0                90
# 2       Shopping     4.3         918.0          100000.0            135038
# 3        Finance     5.0           6.0              50.0                53
# 4   Food & Drink     4.3         830.0          100000.0            142498
#
#    Free  Price Content Rating  Ad Supported  In App Purchases  Editors Choice
# 0     1    0.0       Everyone             0                 0               0
# 1     1    0.0       Everyone             0                 0               0
# 2     1    0.0       Everyone             1                 0               0
# 3     1    0.0       Everyone             0                 0               0
# 4     1    0.0       Everyone             1                 0               0

# %% [markdown]
# we can now tranfrom change some of our data into binary by transforming True into 1 and False into 0

# %%
df
# Out:
#            Category  Rating  Rating Count  Minimum Installs  Maximum Installs  \
# 0     Entertainment     3.9          68.0           10000.0             10291
# 1         Lifestyle     0.0           0.0              50.0                90
# 2          Shopping     4.3         918.0          100000.0            135038
# 3           Finance     5.0           6.0              50.0                53
# 4      Food & Drink     4.3         830.0          100000.0            142498
# ...             ...     ...           ...               ...               ...
# 9994          Music     0.0           0.0              10.0                14
# 9995      Education     4.3         142.0            1000.0              2490
# 9997  Music & Audio     5.0           9.0            1000.0              1035
# 9998  Entertainment     0.0           0.0             500.0               522
# 9999         Casual     4.9          19.0             500.0               656
#
#       Free  Price Content Rating  Ad Supported  In App Purchases  \
# 0        1    0.0       Everyone             0                 0
# 1        1    0.0       Everyone             0                 0
# 2        1    0.0       Everyone             1                 0
# 3        1    0.0       Everyone             0                 0
# 4        1    0.0       Everyone             1                 0
# ...    ...    ...            ...           ...               ...
# 9994     1    0.0       Everyone             0                 0
# 9995     1    0.0       Everyone             0                 0
# 9997     1    0.0           Teen             1                 0
# 9998     1    0.0       Everyone             1                 0
# 9999     1    0.0       Everyone             1                 0
#
#       Editors Choice
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 9994               0
# 9995               0
# 9997               0
# 9998               0
# 9999               0
#
# [9906 rows x 11 columns]

# %%
df.to_csv('../data/Clean_Dataset.csv', index = False)

# %% [markdown]
# ### EDA

# %% [markdown]
# We are checking our target variable

# %%
df['Rating'].value_counts()/df.shape[0]*100.0
# Out:
# 0.0    46.194226
# 5.0     4.320614
# 4.2     4.017767
# 4.4     3.654351
# 4.3     3.563497
# 4.5     3.412073
# 4.6     3.189986
# 4.1     2.988088
# 4.7     2.947708
# 4.0     2.887139
# 4.8     2.796285
# 3.9     2.513628
# 3.8     2.109832
# 4.9     2.109832
# 3.7     1.948314
# 3.6     1.645467
# 3.5     1.494044
# 3.4     1.221482
# 3.3     0.999394
# 3.2     0.908540
# 3.0     0.757117
# 3.1     0.635978
# 2.8     0.555219
# 2.5     0.474460
# 2.9     0.423985
# 2.7     0.423985
# 2.6     0.292752
# 2.3     0.201898
# 2.2     0.191803
# 2.0     0.191803
# 2.4     0.171613
# 1.8     0.151423
# 2.1     0.141328
# 1.6     0.131234
# 1.9     0.100949
# 1.5     0.070664
# 1.4     0.060569
# 1.7     0.040380
# 1.3     0.030285
# 1.2     0.020190
# 1.1     0.010095
# Name: Rating, dtype: float64

# %% [markdown]
# EDA categorical columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9906 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Category          9906 non-null   object
#  1   Rating            9906 non-null   float64
#  2   Rating Count      9906 non-null   float64
#  3   Minimum Installs  9906 non-null   float64
#  4   Maximum Installs  9906 non-null   int64
#  5   Free              9906 non-null   int32
#  6   Price             9906 non-null   float64
#  7   Content Rating    9906 non-null   object
#  8   Ad Supported      9906 non-null   int32
#  9   In App Purchases  9906 non-null   int32
#  10  Editors Choice    9906 non-null   int32
# dtypes: float64(4), int32(4), int64(1), object(2)
# memory usage: 773.9+ KB

# %%
categorical_df = df.select_dtypes('object').copy()
categorical_df.head()
# Out:
#         Category Content Rating
# 0  Entertainment       Everyone
# 1      Lifestyle       Everyone
# 2       Shopping       Everyone
# 3        Finance       Everyone
# 4   Food & Drink       Everyone

# %%
for column in categorical_df.columns[:-1]:

    # Visualize a summary of each
    categorical_df[column].value_counts().sort_values().plot(kind='barh')
    plt.xlabel(column)
    plt.title(column)
    plt.show()

# %% [markdown]
# EDA Numerical columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9906 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Category          9906 non-null   object
#  1   Rating            9906 non-null   float64
#  2   Rating Count      9906 non-null   float64
#  3   Minimum Installs  9906 non-null   float64
#  4   Maximum Installs  9906 non-null   int64
#  5   Free              9906 non-null   int32
#  6   Price             9906 non-null   float64
#  7   Content Rating    9906 non-null   object
#  8   Ad Supported      9906 non-null   int32
#  9   In App Purchases  9906 non-null   int32
#  10  Editors Choice    9906 non-null   int32
# dtypes: float64(4), int32(4), int64(1), object(2)
# memory usage: 773.9+ KB

# %%
numeric_df = df.select_dtypes(['int32','float64', 'int64']).copy()
numeric_df.head()
# Out:
#    Rating  Rating Count  Minimum Installs  Maximum Installs  Free  Price  \
# 0     3.9          68.0           10000.0             10291     1    0.0
# 1     0.0           0.0              50.0                90     1    0.0
# 2     4.3         918.0          100000.0            135038     1    0.0
# 3     5.0           6.0              50.0                53     1    0.0
# 4     4.3         830.0          100000.0            142498     1    0.0
#
#    Ad Supported  In App Purchases  Editors Choice
# 0             0                 0               0
# 1             0                 0               0
# 2             1                 0               0
# 3             0                 0               0
# 4             1                 0               0

# %%
for column in numeric_df:
    plt.figure()
    plt.hist(df[column], bins=25)
    plt.title(column)
    plt.xlabel(column)
    plt.show()

# %%
df.groupby('Rating').mean()
# Out:
# C:\Users\lelon\AppData\Local\Temp\ipykernel_21304\3831588271.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Rating').mean()
#         Rating Count  Minimum Installs  Maximum Installs      Free     Price  \
# Rating
# 0.0         0.000000        542.116914      9.407579e+02  0.986451  0.118089
# 1.1        47.000000       1000.000000      2.212000e+03  1.000000  0.000000
# 1.2        46.000000       1000.000000      2.278000e+03  1.000000  0.000000
# 1.3      1440.666667      33700.000000      1.167567e+05  0.666667  1.496667
# 1.4       238.166667      17166.666667      2.056867e+04  0.833333  2.165000
# 1.5       101.428571      10571.428571      2.026129e+04  1.000000  0.000000
# 1.6       280.307692      52730.769231      7.167062e+04  1.000000  0.000000
# 1.7      2242.000000     253000.000000      3.579080e+05  1.000000  0.000000
# 1.8       187.000000      12380.000000      4.308893e+04  1.000000  0.000000
# 1.9       175.600000      27800.000000      5.127960e+04  1.000000  0.000000
# 2.0       430.736842      68584.210526      1.607479e+05  1.000000  0.000000
# 2.1       121.428571      13357.142857      2.650236e+04  1.000000  0.000000
# 2.2        86.526316       7610.526316      1.276621e+04  1.000000  0.000000
# 2.3       245.750000      16085.000000      3.122975e+04  1.000000  0.000000
# 2.4      1665.411765     140264.705882      2.206271e+05  1.000000  0.000000
# 2.5       475.787234      48538.297872      1.344004e+05  0.978723  0.127447
# 2.6       148.241379      14768.965517      3.587741e+04  1.000000  0.000000
# 2.7       134.095238      15157.142857      3.802152e+04  0.976190  0.061667
# 2.8       159.745455      20447.272727      4.050267e+04  0.981818  0.090727
# 2.9       199.357143      20801.190476      3.375450e+04  0.952381  0.118571
# 3.0       144.840000      15655.333333      2.515320e+04  0.986667  0.013200
# 3.1       213.619048      23938.095238      4.375544e+04  0.984127  0.087143
# 3.2       444.377778      40918.888889      8.163659e+04  0.977778  0.072000
# 3.3       542.171717      91439.393939      1.411319e+05  0.969697  0.060303
# 3.4       803.380165      68614.462810      1.434820e+05  1.000000  0.000000
# 3.5      1497.209459     190979.797297      3.000879e+05  0.972973  0.080811
# 3.6      1137.098160     117638.036810      2.097029e+05  0.975460  0.086503
# 3.7      1065.756477     172325.440415      2.497723e+05  0.974093  0.515285
# 3.8       834.449761      60252.153110      1.191800e+05  0.990431  0.026220
# 3.9      2739.534137     247489.558233      3.906923e+05  0.979920  0.147189
# 4.0      2207.975524     357231.328671      5.801306e+05  0.986014  0.048811
# 4.1      5924.516892     629266.891892      1.550927e+06  1.000000  0.000000
# 4.2      8094.635678     421318.492462      6.922977e+05  0.974874  0.283668
# 4.3      4395.337110     217551.869688      4.593534e+05  0.980170  0.060988
# 4.4      3885.908840     336060.524862      5.891621e+05  0.986188  0.034309
# 4.5      5273.168639     172957.011834      2.990381e+05  0.964497  0.134172
# 4.6      1541.401899      55926.803797      1.067858e+05  0.981013  0.097911
# 4.7      2005.164384      63203.356164      1.070451e+05  0.982877  0.034075
# 4.8      2331.761733      61946.317690      1.195265e+05  0.971119  0.127726
# 4.9       160.086124       3522.440191      6.861761e+03  0.976077  0.037081
# 5.0        20.815421        410.922897      7.927009e+02  0.990654  0.045467
#
#         Ad Supported  In App Purchases  Editors Choice
# Rating
# 0.0         0.416521          0.036058        0.000000
# 1.1         0.000000          0.000000        0.000000
# 1.2         0.000000          0.000000        0.000000
# 1.3         0.333333          0.000000        0.000000
# 1.4         0.500000          0.166667        0.000000
# 1.5         0.142857          0.142857        0.000000
# 1.6         0.384615          0.076923        0.000000
# 1.7         0.000000          0.000000        0.000000
# 1.8         0.200000          0.133333        0.000000
# 1.9         0.400000          0.200000        0.000000
# 2.0         0.210526          0.105263        0.000000
# 2.1         0.714286          0.000000        0.000000
# 2.2         0.421053          0.052632        0.000000
# 2.3         0.100000          0.050000        0.000000
# 2.4         0.470588          0.117647        0.000000
# 2.5         0.574468          0.106383        0.000000
# 2.6         0.275862          0.172414        0.000000
# 2.7         0.428571          0.095238        0.000000
# 2.8         0.454545          0.072727        0.000000
# 2.9         0.309524          0.142857        0.000000
# 3.0         0.546667          0.066667        0.000000
# 3.1         0.444444          0.111111        0.000000
# 3.2         0.488889          0.066667        0.000000
# 3.3         0.535354          0.181818        0.000000
# 3.4         0.578512          0.140496        0.000000
# 3.5         0.560811          0.094595        0.000000
# 3.6         0.582822          0.122699        0.000000
# 3.7         0.544041          0.160622        0.000000
# 3.8         0.583732          0.162679        0.000000
# 3.9         0.646586          0.208835        0.000000
# 4.0         0.650350          0.139860        0.000000
# 4.1         0.652027          0.202703        0.000000
# 4.2         0.625628          0.185930        0.000000
# 4.3         0.677054          0.152975        0.000000
# 4.4         0.682320          0.146409        0.000000
# 4.5         0.627219          0.130178        0.000000
# 4.6         0.629747          0.094937        0.003165
# 4.7         0.616438          0.102740        0.000000
# 4.8         0.458484          0.090253        0.000000
# 4.9         0.454545          0.095694        0.000000
# 5.0         0.453271          0.060748        0.000000

# %%
df.groupby('Rating')['Rating Count'].mean().plot(kind='bar')
plt.xlabel('Rating')
plt.ylabel('Average Rating count')
plt.title('The higher average rating is 4.2')
# Out:
# Text(0.5, 1.0, 'The higher average rating is 4.2')

# %% [markdown]
# ### Prepocessing

# %%
#Listing categorical and numerical columns
cat_cols = df.select_dtypes(include = 'object').columns
num_cols = df.select_dtypes(exclude = 'object').columns

# %%
#Print categorical and numerical columns
print(cat_cols)
print(num_cols)
# Out:
# Index(['Category', 'Content Rating'], dtype='object')
# Index(['Rating', 'Rating Count', 'Minimum Installs', 'Maximum Installs',
#        'Free', 'Price', 'Ad Supported', 'In App Purchases', 'Editors Choice'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                    count           mean           std  min   25%    50%  \
# Rating            9906.0       2.209691  2.108915e+00  0.0   0.0    3.0
# Rating Count      9906.0    1404.259136  2.359045e+04  0.0   0.0    6.0
# Minimum Installs  9906.0   96958.323440  1.685981e+06  0.0  50.0  500.0
# Maximum Installs  9906.0  181538.565718  3.734170e+06  0.0  88.0  734.5
# Free              9906.0       0.983646  1.268381e-01  0.0   1.0    1.0
# Price             9906.0       0.108279  3.050349e+00  0.0   0.0    0.0
# Ad Supported      9906.0       0.501615  5.000226e-01  0.0   0.0    1.0
# In App Purchases  9906.0       0.087018  2.818756e-01  0.0   0.0    0.0
# Editors Choice    9906.0       0.000101  1.004733e-02  0.0   0.0    0.0
#
#                       75%           max
# Rating               4.30  5.000000e+00
# Rating Count        40.75  1.569485e+06
# Minimum Installs  5000.00  1.000000e+08
# Maximum Installs  7113.75  2.955299e+08
# Free                 1.00  1.000000e+00
# Price                0.00  2.699900e+02
# Ad Supported         1.00  1.000000e+00
# In App Purchases     0.00  1.000000e+00
# Editors Choice       0.00  1.000000e+00

# %%
sns.pairplot(df)

# %%
plt.subplots(3, 3, figsize = (10, 10))
i = 1
for num_col in num_cols:
    plt.subplot(3, 3, i)
    plt.hist(df[num_col])
    plt.axvline(df[num_col].mean(), color = 'red')
    plt.title(num_col)
    i += 1

# %%
plt.subplots(2, 1, figsize = (20, 20))
i = 1
for cat_col in cat_cols:
    plt.subplot(2, 1, i)
    plt.bar(df[cat_col].value_counts().index, df[cat_col].value_counts().values)
    plt.title(cat_col)
    i += 1
    
plt.tight_layout()

# %% [markdown]
# ### Linear Regression Model

# %%
X = df['Rating']
y = df['Minimum Installs']

# %%
np.cov(X, y)
# Out:
# array([[4.44752445e+00, 1.84058071e+05],
#        [1.84058071e+05, 2.84253098e+12]])

# %%
df.cov()
# Out:
# C:\Users\lelon\AppData\Local\Temp\ipykernel_21304\1545644723.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#                          Rating  Rating Count  Minimum Installs  \
# Rating                 4.447524  2.847135e+03      1.840581e+05
# Rating Count        2847.135257  5.565093e+08      3.339973e+10
# Minimum Installs  184058.071232  3.339973e+10      2.842531e+12
# Maximum Installs  345418.215042  6.914400e+10      5.967946e+12
# Free                  -0.005354  1.898354e+01      1.519192e+03
# Price                 -0.023773 -1.090896e+02     -9.785073e+03
# Ad Supported           0.171140  4.893682e+02      3.333920e+04
# In App Purchases       0.094230  7.593269e+02      5.432165e+04
# Editors Choice         0.000241  2.465799e+00      9.117029e+01
#
#                   Maximum Installs         Free         Price  Ad Supported  \
# Rating                3.454182e+05    -0.005354     -0.023773      0.171140
# Rating Count          6.914400e+10    18.983542   -109.089619    489.368234
# Minimum Installs      5.967946e+12  1519.192266  -9785.073381  33339.198165
# Maximum Installs      1.394403e+13  2861.121418 -18644.898887  67363.125184
# Free                  2.861121e+03     0.016088     -0.106519      0.006791
# Price                -1.864490e+04    -0.106519      9.304630     -0.041215
# Ad Supported          6.736313e+04     0.006791     -0.041215      0.250023
# In App Purchases      1.062958e+05     0.000515      0.027872      0.021162
# Editors Choice        1.797377e+02     0.000002     -0.000011     -0.000051
#
#                   In App Purchases  Editors Choice
# Rating                    0.094230        0.000241
# Rating Count            759.326868        2.465799
# Minimum Installs      54321.654840       91.170285
# Maximum Installs     106295.754200      179.737651
# Free                      0.000515        0.000002
# Price                     0.027872       -0.000011
# Ad Supported              0.021162       -0.000051
# In App Purchases          0.079454        0.000092
# Editors Choice            0.000092        0.000101

# %%
plt.scatter(df['Rating'], df['Minimum Installs'])
plt.xlabel('Rating')
plt.ylabel('Minimum Installs')
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
np.corrcoef(X,y)
# Out:
# array([[1.        , 0.05176582],
#        [0.05176582, 1.        ]])

# %%
stats.pearsonr(X,y)
# Out:
# PearsonRResult(statistic=0.0517658191959612, pvalue=2.536301692153115e-07)

# %%
X_withconstant = sm.add_constant(X)
X_withconstant
# Out:
#       const  Rating
# 0       1.0     3.9
# 1       1.0     0.0
# 2       1.0     4.3
# 3       1.0     5.0
# 4       1.0     4.3
# ...     ...     ...
# 9994    1.0     0.0
# 9995    1.0     4.3
# 9997    1.0     5.0
# 9998    1.0     0.0
# 9999    1.0     4.9
#
# [9906 rows x 2 columns]

# %%
regression = sm.OLS(y, X_withconstant)
regression_results = regression.fit()
regression_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Minimum Installs   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     26.61
# Date:                Sat, 21 Oct 2023   Prob (F-statistic):           2.54e-07
# Time:                        15:55:37   Log-Likelihood:            -1.5607e+05
# No. Observations:                9906   AIC:                         3.122e+05
# Df Residuals:                    9904   BIC:                         3.122e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5511.6128   2.45e+04      0.225      0.822   -4.25e+04    5.35e+04
# Rating      4.138e+04   8022.421      5.159      0.000    2.57e+04    5.71e+04
# ==============================================================================
# Omnibus:                    30702.923   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2901507588.559
# Skew:                          47.847   Prob(JB):                         0.00
# Kurtosis:                    2652.630   Cond. No.                         4.68
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
